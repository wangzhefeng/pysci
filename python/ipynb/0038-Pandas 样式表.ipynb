# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(23149)
df1 = pd.DataFrame({
    'A': np.linspace(1, 10, 10)
})
df2 = pd.DataFrame(np.random.randn(10, 4), columns = list('BCDE'))
df = pd.concat([df1, df2], axis = 1)
df.iloc[0, 2] = np.nan
df.style
# Out:
# <style  type="text/css" >
# </style><table id="T_9ffec814_376f_11e9_aa73_005056c00008" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9ffec814_376f_11e9_aa73_005056c00008level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9ffec814_376f_11e9_aa73_005056c00008row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_9ffec814_376f_11e9_aa73_005056c00008row0_col1" class="data row0 col1" >0.428903</td>
#                         <td id="T_9ffec814_376f_11e9_aa73_005056c00008row0_col2" class="data row0 col2" >nan</td>
# ...

# %%
df.style.highlight_null().render().split('\n')[:10]
# Out:
# ['<style  type="text/css" >',
#  '    #T_fafb4834_376f_11e9_9802_005056c00008row0_col2 {',
#  '            background-color:  red;',
#  '        }</style><table id="T_fafb4834_376f_11e9_9802_005056c00008" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>',
#  '                <tr>',
#  '                        <th id="T_fafb4834_376f_11e9_9802_005056c00008level0_row0" class="row_heading level0 row0" >0</th>',
#  '                        <td id="T_fafb4834_376f_11e9_9802_005056c00008row0_col0" class="data row0 col0" >1</td>',
#  '                        <td id="T_fafb4834_376f_11e9_9802_005056c00008row0_col1" class="data row0 col1" >0.428903</td>',
# ...

# %% [markdown]
# ## `.style.applymap()`, `.style.apply(, axis, subset)`

# %%
def color_negative_red(val):
    color = 'red' if val < 0 else 'black'
    return 'color: %s' % color

s = df.style.applymap(color_negative_red)
s
# Out:
# <style  type="text/css" >
#     #T_79993868_3771_11e9_a3f0_005056c00008row0_col0 {
#             color:  black;
#         }    #T_79993868_3771_11e9_a3f0_005056c00008row0_col1 {
#             color:  black;
#         }    #T_79993868_3771_11e9_a3f0_005056c00008row0_col2 {
#             color:  black;
#         }    #T_79993868_3771_11e9_a3f0_005056c00008row0_col3 {
#             color:  black;
#         }    #T_79993868_3771_11e9_a3f0_005056c00008row0_col4 {
#             color:  red;
#         }    #T_79993868_3771_11e9_a3f0_005056c00008row1_col0 {
#             color:  black;
#         }    #T_79993868_3771_11e9_a3f0_005056c00008row1_col1 {
#             color:  red;
#         }    #T_79993868_3771_11e9_a3f0_005056c00008row1_col2 {
#             color:  red;
#         }    #T_79993868_3771_11e9_a3f0_005056c00008row1_col3 {
#             color:  red;
#         }    #T_79993868_3771_11e9_a3f0_005056c00008row1_col4 {
#             color:  black;
# ...

# %%
def highlight_max(s):
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

df.style.apply(highlight_max, axis = 1)
# Out:
# <style  type="text/css" >
#     #T_0d660280_3772_11e9_a8f2_005056c00008row0_col0 {
#             background-color:  yellow;
#         }    #T_0d660280_3772_11e9_a8f2_005056c00008row1_col0 {
#             background-color:  yellow;
#         }    #T_0d660280_3772_11e9_a8f2_005056c00008row2_col0 {
#             background-color:  yellow;
#         }    #T_0d660280_3772_11e9_a8f2_005056c00008row3_col0 {
#             background-color:  yellow;
#         }    #T_0d660280_3772_11e9_a8f2_005056c00008row4_col0 {
#             background-color:  yellow;
#         }    #T_0d660280_3772_11e9_a8f2_005056c00008row5_col0 {
#             background-color:  yellow;
#         }    #T_0d660280_3772_11e9_a8f2_005056c00008row6_col0 {
#             background-color:  yellow;
#         }    #T_0d660280_3772_11e9_a8f2_005056c00008row7_col0 {
#             background-color:  yellow;
#         }    #T_0d660280_3772_11e9_a8f2_005056c00008row8_col0 {
#             background-color:  yellow;
# ...

# %%
df.style.apply(highlight_max, axis = 0)
# Out:
# <style  type="text/css" >
#     #T_11fe1268_3772_11e9_8669_005056c00008row2_col3 {
#             background-color:  yellow;
#         }    #T_11fe1268_3772_11e9_8669_005056c00008row3_col2 {
#             background-color:  yellow;
#         }    #T_11fe1268_3772_11e9_8669_005056c00008row4_col4 {
#             background-color:  yellow;
#         }    #T_11fe1268_3772_11e9_8669_005056c00008row6_col1 {
#             background-color:  yellow;
#         }    #T_11fe1268_3772_11e9_8669_005056c00008row9_col0 {
#             background-color:  yellow;
#         }</style><table id="T_11fe1268_3772_11e9_8669_005056c00008" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
# df.style.apply(highlight_max, axis = None)

# %%
df.style \
    .applymap(color_negative_red) \
    .apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_291f6e5c_3772_11e9_85ee_005056c00008row0_col0 {
#             color:  black;
#             : ;
#         }    #T_291f6e5c_3772_11e9_85ee_005056c00008row0_col1 {
#             color:  black;
#             : ;
#         }    #T_291f6e5c_3772_11e9_85ee_005056c00008row0_col2 {
#             color:  black;
#             : ;
#         }    #T_291f6e5c_3772_11e9_85ee_005056c00008row0_col3 {
#             color:  black;
#             : ;
#         }    #T_291f6e5c_3772_11e9_85ee_005056c00008row0_col4 {
#             color:  red;
#             : ;
#         }    #T_291f6e5c_3772_11e9_85ee_005056c00008row1_col0 {
#             color:  black;
#             : ;
#         }    #T_291f6e5c_3772_11e9_85ee_005056c00008row1_col1 {
#             color:  red;
#             : ;
#         }    #T_291f6e5c_3772_11e9_85ee_005056c00008row1_col2 {
#             color:  red;
#             : ;
#         }    #T_291f6e5c_3772_11e9_85ee_005056c00008row1_col3 {
# ...

# %%
def highlight_max(data, color = 'yellow'):
    attr = 'background-color: {}'.format(color)
    if data.ndim == 1:
        is_max = data == data.max()
        return [attr if v else '' for v in is_max]
    else:
        is_max = data == data.max().max()
        return pd.DataFrame(np.where(is_max, attr, ''), 
                            index = data.index, 
                            columns = data.columns)

df.style.apply(highlight_max, color = 'darkorange', axis = None)
# Out:
# <style  type="text/css" >
#     #T_24677386_3773_11e9_bcd5_005056c00008row9_col0 {
#             background-color:  darkorange;
#         }</style><table id="T_24677386_3773_11e9_bcd5_005056c00008" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_24677386_3773_11e9_bcd5_005056c00008level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_24677386_3773_11e9_bcd5_005056c00008row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_24677386_3773_11e9_bcd5_005056c00008row0_col1" class="data row0 col1" >0.428903</td>
# ...

# %%
df.style.apply(highlight_max, subset = ['B', 'C', 'D'])
# Out:
# <style  type="text/css" >
#     #T_ad541d88_3773_11e9_8af1_005056c00008row2_col3 {
#             background-color:  yellow;
#         }    #T_ad541d88_3773_11e9_8af1_005056c00008row3_col2 {
#             background-color:  yellow;
#         }    #T_ad541d88_3773_11e9_8af1_005056c00008row6_col1 {
#             background-color:  yellow;
#         }</style><table id="T_ad541d88_3773_11e9_8af1_005056c00008" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ad541d88_3773_11e9_8af1_005056c00008level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
df.style.apply(highlight_max, subset = ['B', 'C', 'D'], axis = 1)
# Out:
# <style  type="text/css" >
#     #T_b06f24ca_3773_11e9_ae9d_005056c00008row0_col1 {
#             background-color:  yellow;
#         }    #T_b06f24ca_3773_11e9_ae9d_005056c00008row1_col1 {
#             background-color:  yellow;
#         }    #T_b06f24ca_3773_11e9_ae9d_005056c00008row2_col3 {
#             background-color:  yellow;
#         }    #T_b06f24ca_3773_11e9_ae9d_005056c00008row3_col2 {
#             background-color:  yellow;
#         }    #T_b06f24ca_3773_11e9_ae9d_005056c00008row4_col3 {
#             background-color:  yellow;
#         }    #T_b06f24ca_3773_11e9_ae9d_005056c00008row5_col2 {
#             background-color:  yellow;
#         }    #T_b06f24ca_3773_11e9_ae9d_005056c00008row6_col1 {
#             background-color:  yellow;
#         }    #T_b06f24ca_3773_11e9_ae9d_005056c00008row7_col3 {
#             background-color:  yellow;
#         }    #T_b06f24ca_3773_11e9_ae9d_005056c00008row8_col2 {
#             background-color:  yellow;
# ...

# %%
df.style.apply(highlight_max, subset = ['B', 'C', 'D'], axis = None)
# Out:
# <style  type="text/css" >
#     #T_b36edb78_3773_11e9_a55a_005056c00008row6_col1 {
#             background-color:  yellow;
#         }</style><table id="T_b36edb78_3773_11e9_a55a_005056c00008" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b36edb78_3773_11e9_a55a_005056c00008level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b36edb78_3773_11e9_a55a_005056c00008row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_b36edb78_3773_11e9_a55a_005056c00008row0_col1" class="data row0 col1" >0.428903</td>
# ...

# %%
df.style.applymap(color_negative_red, subset = pd.IndexSlice[2:5, ['B', 'D']])
# Out:
# <style  type="text/css" >
#     #T_f1d32538_3773_11e9_a2e9_005056c00008row2_col1 {
#             color:  red;
#         }    #T_f1d32538_3773_11e9_a2e9_005056c00008row2_col3 {
#             color:  black;
#         }    #T_f1d32538_3773_11e9_a2e9_005056c00008row3_col1 {
#             color:  black;
#         }    #T_f1d32538_3773_11e9_a2e9_005056c00008row3_col3 {
#             color:  black;
#         }    #T_f1d32538_3773_11e9_a2e9_005056c00008row4_col1 {
#             color:  black;
#         }    #T_f1d32538_3773_11e9_a2e9_005056c00008row4_col3 {
#             color:  black;
#         }    #T_f1d32538_3773_11e9_a2e9_005056c00008row5_col1 {
#             color:  red;
#         }    #T_f1d32538_3773_11e9_a2e9_005056c00008row5_col3 {
#             color:  red;
# ...

# %% [markdown]
# ## `.style.format()`

# %%
df.style.format('{:.2%}')
# Out:
# <style  type="text/css" >
# </style><table id="T_3253ee40_3774_11e9_afbc_005056c00008" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3253ee40_3774_11e9_afbc_005056c00008level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3253ee40_3774_11e9_afbc_005056c00008row0_col0" class="data row0 col0" >100.00%</td>
#                         <td id="T_3253ee40_3774_11e9_afbc_005056c00008row0_col1" class="data row0 col1" >42.89%</td>
#                         <td id="T_3253ee40_3774_11e9_afbc_005056c00008row0_col2" class="data row0 col2" >nan%</td>
# ...

# %%
df.style.format({
    'B': '{:0<4.0f}',
    'D': '{:+.2f}'
})
# Out:
# <style  type="text/css" >
# </style><table id="T_4ebcd690_3774_11e9_bf9a_005056c00008" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4ebcd690_3774_11e9_bf9a_005056c00008level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4ebcd690_3774_11e9_bf9a_005056c00008row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_4ebcd690_3774_11e9_bf9a_005056c00008row0_col1" class="data row0 col1" >0000</td>
#                         <td id="T_4ebcd690_3774_11e9_bf9a_005056c00008row0_col2" class="data row0 col2" >nan</td>
# ...

# %%
df.style.format({
    'B': lambda x: '±{:.2f}'.format(abs(x))
})
# Out:
# <style  type="text/css" >
# </style><table id="T_3315fbcc_3776_11e9_b9e1_005056c00008" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3315fbcc_3776_11e9_b9e1_005056c00008level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3315fbcc_3776_11e9_b9e1_005056c00008row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_3315fbcc_3776_11e9_b9e1_005056c00008row0_col1" class="data row0 col1" >±0.43</td>
#                         <td id="T_3315fbcc_3776_11e9_b9e1_005056c00008row0_col2" class="data row0 col2" >nan</td>
# ...

# %% [markdown]
# ### `.style.highlight_null(null_color)`

# %%
df.style.highlight_null(null_color = 'red')
# Out:
# <style  type="text/css" >
#     #T_58c3c4b8_3776_11e9_a319_005056c00008row0_col2 {
#             background-color:  red;
#         }</style><table id="T_58c3c4b8_3776_11e9_a319_005056c00008" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_58c3c4b8_3776_11e9_a319_005056c00008level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_58c3c4b8_3776_11e9_a319_005056c00008row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_58c3c4b8_3776_11e9_a319_005056c00008row0_col1" class="data row0 col1" >0.428903</td>
# ...

# %% [markdown]
# ### `.style.background_gradient(cmap)`

# %%
import seaborn as sns
cm = sns.light_palette('green', as_cmap = True)
s = df.style.background_gradient(cmap = cm)
s
# Out:
# D:\Anaconda3\lib\site-packages\numpy\core\_methods.py:32: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial)
# D:\Anaconda3\lib\site-packages\numpy\core\_methods.py:28: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial)
# D:\Anaconda3\lib\site-packages\matplotlib\colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_a71b1592_3776_11e9_98d7_005056c00008row0_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_a71b1592_3776_11e9_98d7_005056c00008row0_col1 {
#             background-color:  #319b31;
#             color:  #000000;
#         }    #T_a71b1592_3776_11e9_98d7_005056c00008row0_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_a71b1592_3776_11e9_98d7_005056c00008row0_col3 {
# ...

# %%
df.style.background_gradient(cmap = 'viridis')
# Out:
# D:\Anaconda3\lib\site-packages\numpy\core\_methods.py:32: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial)
# D:\Anaconda3\lib\site-packages\numpy\core\_methods.py:28: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial)
# D:\Anaconda3\lib\site-packages\matplotlib\colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_d2aaff6c_3776_11e9_9824_005056c00008row0_col0 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_d2aaff6c_3776_11e9_9824_005056c00008row0_col1 {
#             background-color:  #73d056;
#             color:  #000000;
#         }    #T_d2aaff6c_3776_11e9_9824_005056c00008row0_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_d2aaff6c_3776_11e9_9824_005056c00008row0_col3 {
# ...

# %%
(df
    .style
    .background_gradient(cmap = 'viridis', low = 5, high = 0)
    .highlight_null('red'))
# Out:
# D:\Anaconda3\lib\site-packages\numpy\core\_methods.py:32: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial)
# D:\Anaconda3\lib\site-packages\numpy\core\_methods.py:28: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial)
# D:\Anaconda3\lib\site-packages\matplotlib\colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_165771c8_3777_11e9_9f24_005056c00008row0_col0 {
#             background-color:  #90d743;
#             color:  #000000;
#             : ;
#         }    #T_165771c8_3777_11e9_9f24_005056c00008row0_col1 {
#             background-color:  #e7e419;
#             color:  #000000;
#             : ;
#         }    #T_165771c8_3777_11e9_9f24_005056c00008row0_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#             background-color:  red;
# ...

# %% [markdown]
# ### `.style.highlight_max(axis)`, `.style.highlight_min(axis)`

# %%
df.style.highlight_max(axis = 0)
# Out:
# <style  type="text/css" >
#     #T_3506f0d8_3778_11e9_8d1c_005056c00008row2_col3 {
#             background-color:  yellow;
#         }    #T_3506f0d8_3778_11e9_8d1c_005056c00008row3_col2 {
#             background-color:  yellow;
#         }    #T_3506f0d8_3778_11e9_8d1c_005056c00008row4_col4 {
#             background-color:  yellow;
#         }    #T_3506f0d8_3778_11e9_8d1c_005056c00008row6_col1 {
#             background-color:  yellow;
#         }    #T_3506f0d8_3778_11e9_8d1c_005056c00008row9_col0 {
#             background-color:  yellow;
#         }</style><table id="T_3506f0d8_3778_11e9_8d1c_005056c00008" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
df.style.highlight_min(axis = 0)
# Out:
# <style  type="text/css" >
#     #T_83104136_3779_11e9_a2c6_005056c00008row0_col0 {
#             background-color:  yellow;
#         }    #T_83104136_3779_11e9_a2c6_005056c00008row1_col3 {
#             background-color:  yellow;
#         }    #T_83104136_3779_11e9_a2c6_005056c00008row5_col1 {
#             background-color:  yellow;
#         }    #T_83104136_3779_11e9_a2c6_005056c00008row7_col4 {
#             background-color:  yellow;
#         }    #T_83104136_3779_11e9_a2c6_005056c00008row9_col2 {
#             background-color:  yellow;
#         }</style><table id="T_83104136_3779_11e9_a2c6_005056c00008" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %% [markdown]
# ### `.style.properties()`

# %%
styles = {
    'background-color': 'black',
    'color': 'lawngreen',
    'border-color': 'white'
}
df.style.set_properties(**styles)
# Out:
# <style  type="text/css" >
#     #T_ea789046_3779_11e9_97f4_005056c00008row0_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_ea789046_3779_11e9_97f4_005056c00008row0_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_ea789046_3779_11e9_97f4_005056c00008row0_col2 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_ea789046_3779_11e9_97f4_005056c00008row0_col3 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_ea789046_3779_11e9_97f4_005056c00008row0_col4 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_ea789046_3779_11e9_97f4_005056c00008row1_col0 {
#             background-color:  black;
# ...

# %% [markdown]
# ### `.style.bar(subset, color)`

# %%
df.style.bar(subset = ['A', 'B'], color = '#d65f5f')
# Out:
# <style  type="text/css" >
#     #T_f4229666_377a_11e9_ace8_005056c00008row0_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_f4229666_377a_11e9_ace8_005056c00008row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 78.7%, transparent 78.7%);
#         }    #T_f4229666_377a_11e9_ace8_005056c00008row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.1%, transparent 11.1%);
#         }    #T_f4229666_377a_11e9_ace8_005056c00008row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 36.5%, transparent 36.5%);
#         }    #T_f4229666_377a_11e9_ace8_005056c00008row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 22.2%, transparent 22.2%);
# ...

# %%
df.style.bar(subset = ['A', 'B', 'C', 'D', 'E'], align = 'mid', color = ['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_273055d8_377b_11e9_b38a_005056c00008row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 10.0%, transparent 10.0%);
#         }    #T_273055d8_377b_11e9_b38a_005056c00008row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 63.9%, #5fba7d 63.9%, #5fba7d 78.7%, transparent 78.7%);
#         }    #T_273055d8_377b_11e9_b38a_005056c00008row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 63.5%, #5fba7d 63.5%, #5fba7d 72.8%, transparent 72.8%);
#         }    #T_273055d8_377b_11e9_b38a_005056c00008row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 11.7%, #d65f5f 11.7%, #d65f5f 16.2%, transparent 16.2%);
# ...
