# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- --------
# alabaster                     0.7.13
# anyio                         3.7.1
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# asttokens                     2.2.1
# async-lru                     2.0.3
# attrs                         23.1.0
# Babel                         2.12.1
# backcall                      0.2.0
# beautifulsoup4                4.12.2
# bleach                        6.0.0
# causal-learn                  0.1.3.3
# certifi                       2023.5.7
# cffi                          1.15.1
# cfgv                          3.3.1
# charset-normalizer            3.2.0
# cloudpickle                   2.2.1
# colorama                      0.4.6
# comm                          0.1.3
# contourpy                     1.1.0
# cycler                        0.11.0
# Cython                        0.29.36
# ...

# %%
# !pip -V
# Out:
# pip 23.1.2 from D:\software\miniconda3\envs\pysci\lib\site-packages\pip (python 3.9)
