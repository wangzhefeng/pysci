# %%
# !pip list
# Out:
# Package                        Version
# ------------------------------ -------------------
# absl-py                        0.12.0
# aiohttp                        3.7.4.post0
# alabaster                      0.7.12
# alembic                        1.4.1
# anyio                          3.0.1
# appdirs                        1.4.4
# appnope                        0.1.2
# appscript                      1.1.2
# argon2-cffi                    20.1.0
# astunparse                     1.6.3
# async-generator                1.10
# async-timeout                  3.0.1
# attrs                          21.2.0
# ax-platform                    0.2.1
# Babel                          2.9.1
# backcall                       0.2.0
# beautifulsoup4                 4.9.3
# bleach                         3.3.0
# blis                           0.7.4
# Boruta                         0.3
# botorch                        0.5.0
# Bottleneck                     1.3.2
# bs4                            0.0.1
# ...

# %%
# !pip -V
# Out:
# pip 21.2.4 from /Users/zfwang/.pyenv/versions/3.7.10/envs/ml/lib/python3.7/site-packages/pip (python 3.7)
